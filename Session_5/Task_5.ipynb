# %% [markdown]
# # Tuple

# %% [markdown]
# ### `Q1:` Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
# ```
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]
# ```

# %%
test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)] 

unique = [ item[0] for item in test_list]


unique = list(set(unique))

new_list = []
for number in unique:
    new_list.append([number])
    for item in test_list:
        if number == item[0]:
            new_list[-1].append(item[1])



result = list(map(tuple, new_list))
print(result)
# Out:
# [(5, 6, 7, 8), (6, 10), (7, 13)]

# %% [markdown]
# ### `Q2:` Multiply Adjacent elements (both side) and take sum of right and left side multiplication result.
#
#
# For eg.
# ```
# The original tuple : (1, 5, 7, 8, 10)
# Resultant tuple after multiplication :
#
# (1*5, 1*5+5*7, 7*5 + 7*8, 8*7 + 8*10, 10*8) -> (5, 40, 91, 136, 80)
#
# output-(5, 40, 91, 136, 80)
# ```

# %%
a = (1, 5, 7, 8, 10)

a = list(a)


result = []
result.append(a[0] * a[1])
for i in range(1,len(a)-1):
    result.append(a[i]*a[i-1] + a[i]*a[i+1])

result.append(a[-1] * a[-2])
print(result)
# Out:
# [5, 40, 91, 136, 80]

# %% [markdown]
# ### `Q3`: Check is tuples are same or not?
# Two tuples would be same if both tuples have same element at same index
# ```
# t1 = (1,2,3,0)
# t2 = (0,1,2,3)
#
# t1 and t2 are not same

# %%
t1 = (1,2,3,0)
t2 = (0,1,2,3)

flag = True
for i,j in zip(t1,t2):
    if i == j:
        continue
    else:
        flag = False
        break

if flag:
    print("t1 and t2 are equal")
else:
    print("t1 and t2 are not equal")
# Out:
# t1 and t2 are not equal

# %% [markdown]
# ### `Q4`: Count no of tuples, list and set from a list
# ```
# list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
#
# ```
# `Output:`
#
# ```
# List-2
# Set-2
# Tuples-1
# ```

# %%
list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]

dict = {"List": 0, "Tuple": 0, "Set": 0}

for item in list1:
    if type(item) == list:
        dict["List"] += 1
    elif type(item) == tuple:
        dict["Tuple"] += 1
    elif type(item) == set:
        dict["Set"] += 1
    else:
        pass

print(f"List - {dict["List"]}\nTuple - {dict["Tuple"]}\nSet - {dict["Set"]}")
# Out:
# List - 2
# Tuple - 1
# Set - 2

# %% [markdown]
# ### `Q5`: Shortlist Students for a Job role
# Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print `No such candidate`
#
# `Input:`
# ```
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- Manohar
# Enter Higher Education- B.Tech
# Enter Primary Skill- Python
# Enter Year of Graduation- 2022
# Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020
#
# Enter Job Role Requirement
# Enter Skill- Python
# Enter Higher Education- B.Tech
# Enter Year of Graduation- 2022
# ```
#
# `Output`
# ```
# ('Manohar', 'B.tech', 'Python', '2022')
# ```

# %%
n = int(input("Enter Number of Records"))

records = []
for i in range(1, n+1):
    id = int(input("Enter Details of student : "))
    name = input("Enter Name of student : ")
    education = input("Enter Higher Education of student : ")
    skill = input("Enter Primary Skill of student : ")
    year = int(input("Enter Year Of Graduation  of student : "))

    records.append((id,name,education,skill,year))

requirements = []
print("Enter Job Role Requirement")
skill_needed = input("Enter Skill")
education_needed = input("Enter Higher Education")
yog_needed = input("Enter Year of Graduation")

requirements.extend([skill_needed,education_needed,yog_needed])


for id, name, education, skill, year in records:
    if requirements[0] == skill and requirements[1] == education and requirements[2] == year:
        print(f"Student {id} shortlisted")
else:
    print("No candidate found")
# Out:
# Enter Job Role Requirement
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 23
#      19 requirements.extend([skill_needed,education_needed,yog_needed])
#      22 for id, name, education, skill, year in records:
# ---> 23     if requirements[0] == skill and requirements[1] == education and requirements[yog_needed] == year:
#      24         print(f"Student {id} shortlisted")
#      25 else:
#
# TypeError: list indices must be integers or slices, not str
