# %%
# Find the length of a given string without using the len() function

s = input("Enter the string : ")
count = 0
for letter in s:
    count += 1

print(f"The length of the string {s} is {count}")
# Out:
# The length of the string bikash is 6

# %%
# Extract username from a given email. 
# Eg if the email is nitish24singh@gmail.com 
# then the username should be nitish24singh

s = input("Enter your email : ")
index = s.find('@')
print(s[:index])
# Out:
# 5
# medhi

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input("Enter the string")
c = input("Enter your character")
count = 0
for letter in s:
    if letter == c:
        count += 1

print(f"The frequency of the letter {c} in the word {s} is {count}")
# Out:
# The frequency of the letter o in the word You are a very good boy is 4

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ""
for letter in s:
    if letter != term:
        result += letter

print(result)
# Out:
# heo

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')

reversed_s = s[::-1]

if s == reversed_s:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string')
L = []
word = ""
for letter in s:
    
    if letter != " ":
        word += letter
    else:
        L.append(word)
        word = ""
        
L.append(word)
print(len(L))
# Out:
# 4

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = s.split()
new_L = []
for word in L:
    str = word[0].upper() + word[1:].lower()
    new_L.append(str)

result = " ".join(new_L)
print(result)
# Out:
# I Am A Boy Of Assam

# %%
# Write a program that can convert an integer to string.

n = int(input("Enter a number : "))
digits = '0123456789'
result = ""
while n!= 0:
    digit = n % 10
    result = digits[digit] + result
    n = n // 10

print(result)
print(type(result))
# Out:
# 1764
# <class 'str'>
